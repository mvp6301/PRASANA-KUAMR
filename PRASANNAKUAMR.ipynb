# %%
1. What exactly is []?
SSHBCHB
ZHCBHB
# Out:
#   File "C:\Users\CHAITA~1\AppData\Local\Temp/ipykernel_57156/339088408.py", line 1
#     1. What exactly is []?
#        ^
# SyntaxError: invalid syntax

# %%
In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
third value? (Assume [2, 4, 6, 8, 10] are in spam.)
# Out:
#   File "C:\Users\CHAITA~1\AppData\Local\Temp/ipykernel_57156/684400802.py", line 1
#     In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
#        ^
# SyntaxError: invalid syntax
